# %%
import pandas as pd

# %%
file = r'/Users/jojielyn/Downloads/Cleaned_Influencer_Apologies.csv'

data = pd.read_csv(file)

# %%
display(data)
# Out:
#                Name of Influencer   Platform   Date of Apology  \
# 0                   LinusTechTips    YouTube      Aug 16, 2023
# 1                         Watcher    YouTube      Apr 23, 2024
# 2                         RIceGum    YouTube       Jan 4, 2019
# 3                      Liver King    YouTube       Dec 2, 2022
# 4                        JacksFit     TikTok      Jun 29, 2023
# 5                    Kevin Spacey          X      Oct 30, 2017
# 6                   Colleen Vlogs    YouTube      Jun 29, 2023
# 7                            N3ON    YouTube      Mar 17, 2024
# 8                    Tana Mongeau    YouTube      Feb 18, 2017
# 9                 The Gabbie Show    YouTube      Sep 11, 2024
# 10                  Colleen Vlogs    YouTube      May 13, 2020
# 11                  Kara and Nate    YouTube      Jan 28, 2020
# 12                      iDubbbzTV    YouTube      May 19, 2023
# 13                   David Dobrik    YouTube      Mar 23, 2021
# ...
